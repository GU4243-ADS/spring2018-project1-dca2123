# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#the following two lines come from https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.decomposition import NMF,LatentDirichletAllocation

# %% [markdown]
# # SPOOKY Text Data Analysis

# %% [markdown]
# ## Data Retrieval and Cleaning

# %%
spooky = pd.read_csv('..\data\spooky.csv', sep=',', header = 0)

# %%
spooky.head()
# Out:
#         id                                               text author
# 0  id26305  This process, however, afforded me no means of...    EAP
# 1  id17569  It never once occurred to me that the fumbling...    HPL
# 2  id11008  In his left hand was a gold snuff box, from wh...    EAP
# 3  id27763  How lovely is spring As we looked from Windsor...    MWS
# 4  id12958  Finding nothing else, not even gold, the Super...    HPL

# %%
spooky.apply(str)
# Out:
# id        0        id26305\n1        id17569\n2        i...
# text      0        This process, however, afforded me no...
# author    0        EAP\n1        HPL\n2        EAP\n3   ...
# dtype: object

# %%
spooky.shape
# Out:
# (19579, 3)

# %%
eap = spooky.loc[spooky['author'] == 'EAP']
hpl = spooky.loc[spooky['author'] == 'HPL']
mws = spooky.loc[spooky['author'] == 'MWS']

# %%
author_names = ['EAP', 'HPL', 'MWS']
y_pos = np.arange(len(author_names))
num_sent = [len(eap),len(hpl),len(mws)]
 
plt.bar(y_pos, num_sent, align='center', alpha=1)
plt.xticks(y_pos, author_names)
plt.xlabel('Author')
plt.title('Number of Sentences')
 
plt.show()

# %% [markdown]
# ### Sentiment Analysis

# %%
# inspired by http://www.nltk.org/howto/sentiment.html
#from nltk.classify import NaiveBayesClassifier
#from nltk.corpus import subjectivity
#from nltk.sentiment import SentimentAnalyzer

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sia

def avg_sia(sentences):
    
    scores = np.array([])
    for sentence in eap:
        #print(sentence)
        ss = sia.polarity_scores(sentence)
        for k in sorted(ss):
            
            #print('{0}: {1}, '.format(k, ss[k]), end='')

# %% [markdown]
# ## Topic Modeling

# %%
#topic modeling code inspired by https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
#intialize the vectorizers
#this one is for lda
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english')
#below for nmf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=1000, stop_words='english')

# %%
#clean data for nmf
tfidf_eap = tfidf_vectorizer.fit_transform(eap.text)
tfidf_feature_names_eap = tfidf_vectorizer.get_feature_names()

tfidf_hpl = tfidf_vectorizer.fit_transform(hpl.text)
tfidf_feature_names_hpl = tfidf_vectorizer.get_feature_names()

tfidf_mws = tfidf_vectorizer.fit_transform(mws.text)
tfidf_feature_names_mws = tfidf_vectorizer.get_feature_names()

# %%
#clean data for lda
sent_clean = [[],[],[]]
feature_names = [[],[],[]]
t = 0
for series in [eap.text,hpl.text,mws.text]:
    tf = tf_vectorizer.fit_transform(series)
    tf_feature_names = tf_vectorizer.get_feature_names()
    
    sent_clean[t] = tf
    feature_names[t] = tf_feature_names
    t = t + 1

# %%
#this is just for remebering where each author's senetecnes are
eap_clean = sent_clean[0]
hpl_clean = sent_clean[1]
mws_clean = sent_clean[2]

# %%
#some futzing around showed that 15 topics gave some plausible and helful resutls
n_top = 15

# %%
lda_eap = LatentDirichletAllocation(n_topics=n_top, max_iter=5, learning_method='online',learning_offset=50.,random_state=0).fit(eap_clean)
lda_hpl = LatentDirichletAllocation(n_topics=n_top, max_iter=5, learning_method='online',learning_offset=50.,random_state=0).fit(hpl_clean)
lda_mws = LatentDirichletAllocation(n_topics=n_top, max_iter=5, learning_method='online',learning_offset=50.,random_state=0).fit(mws_clean)

# %%
nmf_eap = NMF(n_components=n_top, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf_eap)

nmf_hpl = NMF(n_components=n_top, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf_hpl)

nmf_mws = NMF(n_components=n_top, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf_mws)

# %%
#this cell from https://medium.com/mlreview/topic-modeling-with-scikit-learn-e80d33668730
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("%d:" % (topic_idx))
        s = ' '
        print(s.join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lda_hpl,feature_names[1],10)
# Out:
# 0:
# time years left open seen small sleep hours lay grey
# 1:
# earth past gave face watch period houses known wind stars
# 2:
# did impressions scattered sound dream gilman second held sounds mountain
# 3:
# dreams horror far thought felt did possible eyes sense heard
# 4:
# saw house just windows stone beneath low road fear faces
# 5:
# door light ancient room began heard window shall tried secret
# 6:
# old man told little white terrible black innsmouth gods strange
# 7:
# things place life knew said death say strange human west
# 8:
# voice reached got moment head eyes brain greater blue rest
# 9:
# hour going near kind arkham whateley stood case large son
# 10:
# men night young city mind business came went march till
# 11:
# like april ye water end looked night streets aout kept
# 12:
# day come grew heavy order doubt walls paper consciousness occurred
# 13:
# thing half hideous sight world hand odd having god suddenly
# 14:
# new great know people street england wilcox laid certain did

# %%
display_topics(nmf_hpl,tfidf_feature_names_hpl,10)
# Out:
# 0:
# things heard house strange place long thought said door told
# 1:
# did looked come expected dare sleep father understand wish look
# 2:
# man bearded dead black young say terrible face spoke said
# 3:
# night day sleep went wind slept late unknown zann room
# 4:
# like ye face looked folks em head light didn abaout
# 5:
# saw moon light form glow brown room sight beginning feet
# 6:
# thing laboratory horror occurred ve terrible try eyes nameless resolved
# 7:
# men young dreams sinister land morning arkham fact went told
# 8:
# west fresh dr dead work friend college war specimens east
# 9:
# great war ones cthulhu say god grandfather said half size
# 10:
# time space new help passed got soon certain fear reached
# 11:
# old woman ones people years new house folk seen terrible
# 12:
# knew death evil stop st kept armitage felt grave people
# 13:
# came door moon horror object street passed long outside sounds
# 14:
# know life don ye shall dun tell things said believe

# %%
tfidf_feature_names_hpl
# Out:
# ['abaout',
#  'able',
#  'abnormal',
#  'abyss',
#  'abysses',
#  'account',
#  'accursed',
#  'action',
#  'actual',
#  'actually',
#  'aeons',
#  'afraid',
#  'afternoon',
#  'afterward',
#  'age',
#  'aged',
#  'ago',
#  'ahead',
#  'aid',
#  'ain',
#  'air',
#  'aira',
#  'alive',
#  'amidst',
#  'ancient',
#  'animals',
#  'antique',
#  'antiquity',
#  'anxious',
#  'aout',
#  'apparently',
#  'appearance',
#  'appeared',
#  'approached',
#  'april',
#  'arkham',
#  'armitage',
#  'arms',
#  'aroused',
#  'art',
#  'arter',
#  'arthur',
#  'ask',
#  'asked',
#  'aspect',
#  'atal',
#  'attention',
#  'attic',
#  'autumn',
#  'awake',
#  'awaked',
#  'away',
#  'awful',
#  'bad',
#  'barry',
#  'barzai',
#  'base',
#  'bear',
#  'beard',
#  'bearded',
#  'bearing',
#  'beauty',
#  'bed',
#  'began',
#  'beginning',
#  'begun',
#  'beheld',
#  'behold',
#  'beings',
#  'believe',
#  'believed',
#  'ben',
#  'beneath',
#  'bent',
#  'best',
#  'better',
#  'big',
#  'birch',
#  'bit',
#  'black',
#  'blasphemous',
#  'blood',
#  'blue',
#  'boat',
#  'bodies',
#  'body',
#  'bog',
#  'bolt',
#  'book',
#  'books',
#  'bore',
#  'born',
#  'boston',
#  'box',
#  'boy',
#  'brain',
#  'brick',
#  'bridge',
#  'bring',
#  'broke',
#  'broken',
#  'brought',
#  'brown',
#  'building',
#  'built',
#  'buried',
#  'burned',
#  'burst',
#  'bus',
#  'business',
#  'called',
#  'came',
#  'care',
#  'carefully',
#  'carried',
#  'carter',
#  'carven',
#  'case',
#  'cast',
#  'castle',
#  'cats',
#  'caught',
#  'cause',
#  'caused',
#  'ceased',
#  'cellar',
#  'centre',
#  'centuries',
#  'century',
#  'certain',
#  'certainly',
#  'chair',
#  'chamber',
#  'chance',
#  'change',
#  'changed',
#  'chaos',
#  'child',
#  'children',
#  'chimney',
#  'church',
#  'cities',
#  'city',
#  'clear',
#  'clearly',
#  'cliff',
#  'climb',
#  'climbed',
#  'clock',
#  'close',
#  'closed',
#  'closely',
#  'clothes',
#  'cloud',
#  'clouds',
#  'coffin',
#  'cohort',
#  'cold',
#  'college',
#  'come',
#  'coming',
#  'commenced',
#  'common',
#  'complete',
#  'concerning',
#  'connected',
#  'conscious',
#  'consciousness',
#  'continued',
#  'corner',
#  'corpse',
#  'cosmic',
#  'cottage',
#  'country',
#  'countryside',
#  'course',
#  'covered',
#  'creature',
#  'creatures',
#  'crossed',
#  'crowd',
#  'crude',
#  'crumbling',
#  'cthulhu',
#  'cult',
#  'curiosity',
#  'curious',
#  'curiously',
#  'curse',
#  'cut',
#  'daemon',
#  'daemoniac',
#  'damp',
#  'daown',
#  'dare',
#  'dared',
#  'dark',
#  'darkness',
#  'data',
#  'dawn',
#  'day',
#  'days',
#  'dead',
#  'death',
#  'decay',
#  'decided',
#  'deep',
#  'deeper',
#  'deeply',
#  'definite',
#  'depths',
#  'deserted',
#  'despite',
#  'determined',
#  'devil',
#  'did',
#  'didn',
#  'died',
#  'different',
#  'dim',
#  'direction',
#  'disappeared',
#  'discovered',
#  'distance',
#  'distant',
#  'disturbed',
#  'doctor',
#  'dogs',
#  'don',
#  'door',
#  'doubt',
#  'dr',
#  'dragged',
#  'drawn',
#  'dread',
#  'dreaded',
#  'dream',
#  'dreamed',
#  'dreams',
#  'drew',
#  'dropped',
#  'dun',
#  'dunwich',
#  'dusk',
#  'dwelt',
#  'dying',
#  'early',
#  'ears',
#  'earth',
#  'east',
#  'edge',
#  'ef',
#  'effect',
#  'elder',
#  'electric',
#  'elwood',
#  'em',
#  'end',
#  'england',
#  'english',
#  'entered',
#  'entity',
#  'escape',
#  'especially',
#  'evening',
#  'events',
#  'evidently',
#  'evil',
#  'exceedingly',
#  'excited',
#  'existence',
#  'expected',
#  'experience',
#  'expression',
#  'eye',
#  'eyed',
#  'eyes',
#  'face',
#  'faces',
#  'fact',
#  'failed',
#  'faint',
#  'fairly',
#  'fall',
#  'fallen',
#  'familiar',
#  'family',
#  'fancied',
#  'fancy',
#  'fantastic',
#  'far',
#  'farmhouse',
#  'fashion',
#  'father',
#  'fear',
#  'feared',
#  'fears',
#  'features',
#  'feeble',
#  'feel',
#  'feet',
#  'fell',
#  'fellow',
#  'felt',
#  'fer',
#  'field',
#  'figure',
#  'figures',
#  'filled',
#  'final',
#  'finally',
#  'finding',
#  'fish',
#  'flame',
#  'flash',
#  'flashlight',
#  'floor',
#  'folk',
#  'folks',
#  'followed',
#  'following',
#  'foot',
#  'forbidden',
#  'force',
#  'forced',
#  'forest',
#  'forgotten',
#  'form',
#  'formed',
#  'forms',
#  'forth',
#  'frantic',
#  'free',
#  'frequent',
#  'fresh',
#  'friend',
#  'fright',
#  'frightened',
#  'frightful',
#  'fully',
#  'furniture',
#  'furtive',
#  'future',
#  'gardens',
#  'garret',
#  'gate',
#  'gave',
#  'general',
#  'gentle',
#  'german',
#  'getting',
#  'ghastly',
#  'gigantic',
#  'gilman',
#  'git',
#  'given',
#  'glad',
#  'glance',
#  'glass',
#  'glen',
#  'glimpse',
#  'glimpsed',
#  'glow',
#  'god',
#  'gods',
#  'going',
#  'gold',
#  'golden',
#  'gone',
#  'good',
#  'got',
#  'gradually',
#  'grandfather',
#  'grave',
#  'great',
#  'greater',
#  'greatest',
#  'green',
#  'grew',
#  'grey',
#  'grotesque',
#  'ground',
#  'group',
#  'grove',
#  'grow',
#  'growing',
#  'grown',
#  'guess',
#  'hair',
#  'half',
#  'hall',
#  'hand',
#  'hands',
#  'happened',
#  'harbour',
#  'hard',
#  'hardly',
#  'harris',
#  'hatheg',
#  'haunted',
#  'having',
#  'head',
#  'heads',
#  'hear',
#  'heard',
#  'heaven',
#  'heavy',
#  'heerd',
#  'heh',
#  'height',
#  'held',
#  'hellish',
#  'help',
#  'hidden',
#  'hideous',
#  'high',
#  'higher',
#  'hill',
#  'hills',
#  'hillside',
#  'hint',
#  'hold',
#  'home',
#  'hope',
#  'horizon',
#  'horrible',
#  'horribly',
#  'horror',
#  'horrors',
#  'horse',
#  'host',
#  'hotel',
#  'hour',
#  'hours',
#  'house',
#  'houses',
#  'huge',
#  'human',
#  'ice',
#  'idea',
#  'ill',
#  'image',
#  'imagination',
#  'imagine',
#  'impossible',
#  'impression',
#  'impressions',
#  'increased',
#  'information',
#  'innsmouth',
#  'insane',
#  'instant',
#  'instead',
#  'iranon',
#  'iron',
#  'island',
#  'ivory',
#  'jermyn',
#  'joe',
#  'johansen',
#  'john',
#  'just',
#  'kalos',
#  'kept',
#  'key',
#  'keziah',
#  'kin',
#  'kind',
#  'king',
#  'kingsport',
#  'knew',
#  'know',
#  'knowledge',
#  'known',
#  'knows',
#  'laboratory',
#  'laid',
#  'lake',
#  'lamp',
#  'land',
#  'language',
#  'large',
#  'late',
#  'later',
#  'laughed',
#  'laws',
#  'lay',
#  'leading',
#  'learned',
#  'leave',
#  'leaving',
#  'led',
#  'left',
#  'legend',
#  'legends',
#  'legrasse',
#  'length',
#  'let',
#  'level',
#  'library',
#  'lie',
#  'life',
#  'light',
#  'lightning',
#  'lights',
#  'like',
#  'line',
#  'lines',
#  'lips',
#  'listen',
#  'listened',
#  'little',
#  'live',
#  'lived',
#  'lives',
#  'living',
#  'll',
#  'loathsome',
#  'local',
#  'lock',
#  'locked',
#  'lonely',
#  'long',
#  'longer',
#  'look',
#  'looked',
#  'looking',
#  'lore',
#  'lost',
#  'lot',
#  'louder',
#  'loved',
#  'low',
#  'lower',
#  'lurking',
#  'mad',
#  'madness',
#  'magic',
#  'main',
#  'make',
#  'making',
#  'man',
#  'mankind',
#  'manner',
#  'mansion',
#  'manuscript',
#  'marble',
#  'march',
#  'marsh',
#  'martense',
#  'material',
#  'matter',
#  'means',
#  'meant',
#  'meet',
#  'memories',
#  'memory',
#  'men',
#  'mental',
#  'merely',
#  'met',
#  'midnight',
#  'mighty',
#  'mind',
#  'miskatonic',
#  'mists',
#  'mixed',
#  'modern',
#  'moment',
#  'monster',
#  'monstrous',
#  'months',
#  'moon',
#  'moonlight',
#  'morbid',
#  'morning',
#  'mother',
#  'motion',
#  'mould',
#  'mountain',
#  'moved',
#  'mr',
#  'museum',
#  'music',
#  'musides',
#  'mystery',
#  'nameless',
#  'narrow',
#  'natives',
#  'natural',
#  'nature',
#  'near',
#  'nearer',
#  'nearly',
#  'necronomicon',
#  'need',
#  'nervous',
#  'new',
#  'night',
#  'nightmare',
#  'noise',
#  'noises',
#  'normal',
#  'north',
#  'note',
#  'notes',
#  'notice',
#  'noticed',
#  'number',
#  'obed',
#  'object',
#  'objects',
#  'obscure',
#  'obtained',
#  'occurred',
#  'ocean',
#  'odd',
#  'oddly',
#  'odour',
#  'old',
#  'older',
#  'ones',
#  'open',
#  'opened',
#  'opening',
#  'order',
#  'organic',
#  'original',
#  'ought',
#  'outside',
#  'pair',
#  'pale',
#  'paper',
#  'papers',
#  'partly',
#  'parts',
#  'party',
#  'pass',
#  'passage',
#  'passed',
#  'past',
#  'peak',
#  'peculiar',
#  'people',
#  'period',
#  'person',
#  'persons',
#  'physical',
#  'physician',
#  'pickman',
#  'picture',
#  'piece',
#  'pillars',
#  'piping',
#  'place',
#  'places',
#  'plain',
#  'pocket',
#  'point',
#  'police',
#  'poor',
#  'position',
#  'possessed',
#  'possible',
#  'power',
#  'prepared',
#  'presence',
#  'present',
#  'prints',
#  'probably',
#  'professor',
#  'progress',
#  'proved',
#  'public',
#  'pull',
#  'quality',
#  'queer',
#  'quest',
#  'questions',
#  'quickly',
#  'quiet',
#  'quite',
#  'rain',
#  'ran',
#  'rat',
#  'reach',
#  'reached',
#  'read',
#  'reading',
#  'real',
#  'realised',
#  'reality',
#  'really',
#  'reason',
#  'recall',
#  'red',
#  'reef',
#  'region',
#  'relief',
#  'remained',
#  'remains',
#  'remarkable',
#  'remember',
#  'remembered',
#  'remote',
#  'repeated',
#  'repellent',
#  'resolved',
#  'rest',
#  'results',
#  'return',
#  'returned',
#  'revealed',
#  'right',
#  'rise',
#  'rising',
#  'river',
#  'road',
#  'rock',
#  'roman',
#  'romero',
#  'roof',
#  'roofs',
#  'room',
#  'rooms',
#  'rose',
#  'rotting',
#  'ruined',
#  'ruins',
#  'run',
#  'said',
#  'sailed',
#  'sarnath',
#  'sat',
#  'save',
#  'saw',
#  'say',
#  'says',
#  'scarcely',
#  'scattered',
#  'scene',
#  'school',
#  'scientific',
#  'scream',
#  'screamed',
#  'screaming',
#  'sea',
#  'second',
#  'secret',
#  'secrets',
#  'seen',
#  'seized',
#  'seldom',
#  'sense',
#  'senses',
#  'sent',
#  'servants',
#  'set',
#  'shadow',
#  'shadows',
#  'shall',
#  'shapes',
#  'sharp',
#  'sheehan',
#  'sheer',
#  'shew',
#  'shewed',
#  'shewing',
#  'ship',
#  'shock',
#  'shocking',
#  'shore',
#  'short',
#  'shrieking',
#  'shuddered',
#  'shunned',
#  'shut',
#  'sides',
#  'sight',
#  'sights',
#  'signs',
#  'silence',
#  'silent',
#  'simple',
#  'single',
#  'singular',
#  'sinister',
#  'sir',
#  'size',
#  'skull',
#  'sky',
#  'slab',
#  'slanting',
#  'slater',
#  'sleep',
#  'slept',
#  'slight',
#  'slope',
#  'slowly',
#  'small',
#  'smell',
#  'soft',
#  'solid',
#  'solution',
#  'somewhat',
#  'son',
#  'songs',
#  'soon',
#  'sort',
#  'sought',
#  'soul',
#  'sound',
#  'sounds',
#  'source',
#  'south',
#  'space',
#  'speak',
#  'specimen',
#  'specimens',
#  'spectral',
#  'speech',
#  'spent',
#  'spirit',
#  'spoke',
#  'spot',
#  'spread',
#  'spring',
#  'square',
#  'squatters',
#  'st',
#  'stairs',
#  'standing',
#  'star',
#  'staring',
#  'stars',
#  'started',
#  'state',
#  'steep',
#  'stench',
#  'steps',
#  'stone',
#  'stones',
#  'stood',
#  'stop',
#  'stopped',
#  'storm',
#  'story',
#  'strange',
#  'strangely',
#  'stranger',
#  'street',
#  'streets',
#  'stricken',
#  'strong',
#  'struck',
#  'studied',
#  'studies',
#  'study',
#  'sudden',
#  'suddenly',
#  'suggested',
#  'suggestion',
#  'summer',
#  'sun',
#  'sure',
#  'surface',
#  'suspected',
#  'swamp',
#  'table',
#  'taken',
#  'tale',
#  'tales',
#  'talk',
#  'talked',
#  'tall',
#  'tell',
#  'tempest',
#  'temple',
#  'terrible',
#  'terror',
#  'th',
#  'thing',
#  'things',
#  'think',
#  'thirty',
#  'thought',
#  'thoughts',
#  'thunder',
#  'till',
#  'tillinghast',
#  'time',
#  'times',
#  'tiny',
#  'told',
#  'tomb',
#  'took',
#  'touch',
#  'tower',
#  'town',
#  'trace',
#  'tracks',
#  'trees',
#  'trever',
#  'tried',
#  'trouble',
#  'true',
#  'truth',
#  'try',
#  'turn',
#  'turned',
#  'twilight',
#  'uncle',
#  'understand',
#  'university',
#  'unknown',
#  'unnatural',
#  'unseen',
#  'unusual',
#  'upper',
#  'use',
#  'used',
#  'usual',
#  'utter',
#  'utterly',
#  'vague',
#  'vaguely',
#  'valley',
#  'vanished',
#  'various',
#  'vast',
#  'vault',
#  've',
#  'view',
#  'village',
#  'violet',
#  'visible',
#  'vision',
#  'visions',
#  'visit',
#  'voice',
#  'voices',
#  'waited',
#  'waking',
#  'walk',
#  'walked',
#  'walking',
#  'wall',
#  'walls',
#  'want',
#  'war',
#  'warren',
#  'watch',
#  'watched',
#  'water',
#  'waters',
#  'waves',
#  'way',
#  'ways',
#  'week',
#  'weird',
#  'went',
#  'west',
#  'whateley',
#  'whilst',
#  'whisper',
#  'whispered',
#  'white',
#  'wholly',
#  'wide',
#  'wife',
#  'wilbur',
#  'wilcox',
#  'wild',
#  'wildly',
#  'wind',
#  'window',
#  'windows',
#  'wish',
#  'wished',
#  'witch',
#  'woman',
#  'wonder',
#  'wondered',
#  'wood',
#  'woods',
#  'words',
#  'wore',
#  'work',
#  'world',
#  'worst',
#  'written',
#  'wrote',
#  'ye',
#  'year',
#  'years',
#  'yellow',
#  'young',
#  'youth',
#  'zadok',
#  'zann']
